# %% [markdown]
# Bubble Sort

# %%
def bubblesort(a):
    for i in range(len(a)-1):
        for j in range(len(a)-1):
            if a[j]>a[j+1]:
               a[j],a[j+1]=a[j+1],a[j]
    for i in range(len(a)):
          print(a[i],end=" ")
list1=[19,1,25,6,18,3]
bubblesort(list1)
# Out:
# 1 3 6 18 19 25

# %% [markdown]
# ASCII Numbers

# %%
str=("Application")
print(str)

str1='Application'
print(str1)

str2="""Application Test
       working
       Completed
       List
       Strings
       Python """
print(str2)
# Out:
# Application
# Application
# Application Test
#        working
#        Completed
#        List
#        Strings
#        Python

# %% [markdown]
# Example

# %%
def countofchars(str):
  return len(str)
countofchars("Application")
# Out:
# 11

# %%
def countdigits(n):
  return len(n)
countdigits("25418")
# Out:
# 5

# %% [markdown]
# String Examples

# %%
def countuppercase(s):
    count=0
    lst=list(s)
    for x in range(len(lst)):
      if ord(lst[x]) >= 65 and ord(lst[x]) <= 90:
         count+=1
    return count
  
  
  
print(countuppercase("TEST"))
# Out:
# 4

# %% [markdown]
# Example 2

# %%
def printDigits(str):
    lst=list(str)
    for x in range(len(lst)):
        if ord(lst[x])>=48 and ord(lst[x])<=57:
            print(lst[x],end="")
    return
  
printDigits('Application1889')
# Out:
# 1889

# %% [markdown]
# Sum of Digits

# %%
def sumofdigits(str):
    sum=0
    lst=list(str)
    for x in range(len(lst)):
        if ord(lst[x])>=48 and ord(lst[x])<=57:
           sum=sum+ord(lst[x]) -48
    return sum
print(sumofdigits('Application1889'))
# Out:
# 26

# %% [markdown]
# Strings--Add only even digits to sum

# %%
def sumofevendigits(str):
    sum=0
    lst=list(str)
    for x in range(len(lst)):
        if ord(lst[x])>=48 and ord(lst[x])<=57:
            if ord(lst[x])%2==0:
               sum=sum+ord(lst[x])-48
    return sum

print(sumofevendigits('Wor7852king'))
# Out:
# 10

# %% [markdown]
# Binary Search

# %%
def binarysearch(a,lIndex,rIndex,tarItem):
    while(lIndex<=rIndex):
      mIndex=lIndex+(rIndex-lIndex)//2
      if a[mIndex]==tarItem:
          return mIndex
      if a[mIndex]>tarItem:
          rIndex=mIndex-1
      else:
          lIndex=mIndex-1
    return -1
  
list1=[1,4,9,15,25,45,57,88,98]
res=binarysearch(list1,0,8,98)
if res!=-1:
    print("Item is found")
else:
    print("Item is not found")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-3fb1b472ab28> in <module>()
#      11
#      12 list1=[1,4,9,15,25,45,57,88,98]
# ---> 13 res=binarysearch(list1,0,8,98)
#      14 if res!=-1:
#      15     print("Item is found")
#
# <ipython-input-48-3fb1b472ab28> in binarysearch(a, lIndex, rIndex, tarItem)
#       7           rIndex=mIndex-1
#       8       else:
# ----> 9           lIndex=mIndex-1
#      10     return -1
#      11
#
# KeyboardInterrupt:
